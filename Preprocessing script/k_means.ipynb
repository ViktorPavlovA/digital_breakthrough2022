# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
#from seaborn import sns

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/MyDrive/Colab\ Notebooks/datasets/competition2022/
# Out:
# /content/drive/MyDrive/Colab Notebooks/datasets/competition2022

# %%
# !ls
# Out:
# 0.1train.csv  test.csv	   train.csv	 train_v7.csv
# 0.2train.csv  test_v7.csv  train_v3.csv  train_v8.csv
# 0.3train.csv  test_v8.csv  trainv4.csv	 trainv9.csv

# %%
table1 = pd.read_csv("train_v7.csv",sep=',',error_bad_lines=False,index_col=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd_test = pd.read_csv("test_v7.csv",sep=',',error_bad_lines=False,index_col=False)

# %%
pd_test = pd_test.fillna(-1)

# %%
table1 = table1.fillna(-1)

# %%
table1
# Out:
#         label      period      subject_type subject_name   city_name  \
# 0           1  2020-06-01           Область    Калужская    Козельск
# 1           1  2020-06-01           Область    Калужская    Курилово
# 2           1  2020-06-01           Область    Калужская  Балабаново
# 3           1  2020-06-01           Область    Калужская   Сосенский
# 4           1  2020-06-01           Область    Калужская     Обнинск
# ...       ...         ...               ...          ...         ...
# 294253      0  2020-12-01           Область  Магаданская     Магадан
# 294254      0  2020-12-01           Область  Магаданская         Ола
# 294255      0  2020-12-01           Область  Магаданская     Магадан
# 294256      0  2020-12-01  Автономный Округ    Чукотский       Певек
# 294257      0  2020-12-01  Автономный Округ    Чукотский       Певек
#
#                     hex    hex_lat     hex_lon       f1       f2  ...  \
# ...

# %%
# classifier = KNeighborsClassifier(n_neighbors=10)

# %%
# for i in range(len(list(table1.columns.values))):
#   print(i,list(table1.columns.values)[i])

# %%
# y = table1['label']

# %%
X = table1.iloc[:, 8:38]

# %%
X_test = pd_test.iloc[:, 8:38]

# %%
# kmeans = classifier.fit(X,y)

# %% [markdown]
# Классификатор

# %%
# pred = classifier.predict(X) #очень долго

# %%
scaler_X = MinMaxScaler()
scale = scaler_X.fit_transform(X)

# %%
scale_test =scaler_X.transform(X_test)

# %%
X = pd.DataFrame(scale)

# %%
X_test = pd.DataFrame(scale_test)

# %%
km=KMeans(n_clusters=100,random_state=1)
y_predicted = km.fit_predict(scale)

# %%
y_test = km.predict(scale_test)

# %%
scale_test
# Out:
# array([[0.76279282, 0.77506903, 0.78336315, ..., 0.        , 0.50249   ,
#         0.8       ],
#        [0.76258747, 0.77618278, 0.78403506, ..., 0.        , 0.501665  ,
#         0.8       ],
#        [0.76092181, 0.7738934 , 0.78190214, ..., 0.        , 0.50452   ,
#         0.8       ],
#        ...,
#        [0.76321874, 0.77619825, 0.78445696, ..., 0.86174   , 0.50625   ,
#         0.8       ],
#        [0.76061758, 0.77348348, 0.78135523, ..., 0.876545  , 0.511265  ,
#         0.8       ],
#        [0.76073928, 0.77367684, 0.78160524, ..., 0.958335  , 0.51      ,
#         0.8       ]])

# %%
y_predicted
# Out:
# array([ 0,  0,  0, ..., 99,  5,  5], dtype=int32)

# %%
table1["KMeans(100)"] = y_predicted

# %%
table1
# Out:
#         label      period      subject_type subject_name   city_name  \
# 0           1  2020-06-01           Область    Калужская    Козельск
# 1           1  2020-06-01           Область    Калужская    Курилово
# 2           1  2020-06-01           Область    Калужская  Балабаново
# 3           1  2020-06-01           Область    Калужская   Сосенский
# 4           1  2020-06-01           Область    Калужская     Обнинск
# ...       ...         ...               ...          ...         ...
# 294253      0  2020-12-01           Область  Магаданская     Магадан
# 294254      0  2020-12-01           Область  Магаданская         Ола
# 294255      0  2020-12-01           Область  Магаданская     Магадан
# 294256      0  2020-12-01  Автономный Округ    Чукотский       Певек
# 294257      0  2020-12-01  Автономный Округ    Чукотский       Певек
#
#                     hex    hex_lat     hex_lon       f1       f2  ...  count  \
# ...

# %%
table2 = pd.read_csv("train_v7.csv",sep=',',error_bad_lines=False,index_col=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
table2["KMeans(100)"] = y_predicted

# %%
table2.to_csv("train_v8.csv")

# %%
table_test = pd.read_csv("test_v7.csv",sep=',',error_bad_lines=False,index_col=False)

# %%
table_test["KMeans(100)"] = y_test

# %%
table_test
# Out:
#         label      period subject_type subject_name      city_name  \
# 0           1  2020-11-01        Город       Москва         Москва
# 1           1  2020-11-01        Город       Москва         Москва
# 2           1  2020-11-01        Город       Москва         Москва
# 3           1  2020-11-01        Город       Москва         Москва
# 4           1  2020-11-01        Город       Москва         Москва
# ...       ...         ...          ...          ...            ...
# 152761      0  2021-05-01   Республика        Алтай   Владимировка
# 152762      0  2021-05-01   Республика        Алтай  Горно-Алтайск
# 152763      0  2021-05-01   Республика        Алтай          Майма
# 152764      0  2021-05-01   Республика        Алтай  Горно-Алтайск
# 152765      0  2021-05-01   Республика        Алтай          Майма
#
#                     hex    hex_lat    hex_lon       f1       f2  ...   count  \
# 0       8611aa6b7ffffff  55.656639  37.774902  0.00292  0.00211  ...   562.0
# ...

# %%
table_test.to_csv("test_v8.csv")
